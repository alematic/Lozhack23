# %%
import pandas as pd

tr_aff= pd.read_csv('data/Transporter-drug_affinity_data_based_on_cell_line_experiment.txt',sep='\t')
end_metab=pd.read_csv('data/EMs_handled_by_DTs_identified_using_KO_mice_cell_lines_patient_clinical_data.txt',sep='\t')
tr_nameid = pd.read_csv('data/Cross-matching_ID_between_the_DTs_and_a_variety_of_public_databases.txt',sep='\t')

tr_nameid
# Out:
#     TransporterID Gene_name  \
# 0         DTD0103  SLC16A12
# 1         DTD0166   SLC24A5
# 2         DTD0320   SLC36A3
# 3         DTD0343   SLC39A2
# 4         DTD0370   SLC45A3
# ..            ...       ...
# 418       DTD0451   SLC6A19
# 419       DTD0052     ABCB6
# 420       DTD0483    SLC9A3
# 421       DTD0477    SLC8A1
# 422       DTD0105  SLC16A14
#
#                                 Protein_Name_generally  Gene_id Uniprot ID  \
# 0                       Monocarboxylate transporter 12   387700     Q6ZSM3
# 1                 Sodium/potassium/calcium exchanger 5   283652     Q71RS6
# 2              Proton-coupled amino acid transporter 3   285641     Q495N2
# 3                          Zrt- and Irt-like protein 2    29986     Q9NP94
# 4                    Solute carrier family 45 member 3    85414     Q96JT2
# ..                                                 ...      ...        ...
# 418  Sodium-dependent neutral amino acid transporte...   340024     Q695T7
# 419         ATP-binding cassette sub-family B member 6    10058     Q9NP58
# 420                        Sodium/hydrogen exchanger 3     6550     P48764
# 421                         Sodium/calcium exchanger 1     6546     P32418
# 422                     Monocarboxylate transporter 14   151473     Q7RTX9
#
#          TCDB ID
# 0    2.A.1.13.14
# 1     2.A.19.4.6
# 2     2.A.18.8.4
# 3      2.A.5.3.1
# 4      2.A.2.4.8
# ..           ...
# 418   2.A.22.6.3
# 419  3.A.1.210.6
# 420  2.A.36.1.15
# 421   2.A.19.3.4
# 422  2.A.1.13.12
#
# [423 rows x 6 columns]

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://transportal.compbio.ucsf.edu/index/'
res = requests.get(url)
# print(res.text) # Uncomment to see the HTML


soup = BeautifulSoup(res.text, 'html.parser')

# Find all <a> tags and filter for hrefs that meet criteria
transporter_entries = soup.find_all('a', href=True)
#what is the type of transporter_entries
type(transporter_entries)

#filter from tranpsorter_entries all the entries that have /transporters/ inside
transporter_entries = [entry for entry in transporter_entries if '/transporters/' in entry.get('href')]

#filter out also the mouse and rat entries
transporter_entries = [entry for entry in transporter_entries if not '/transporters/mouse' in entry.get('href')]
transporter_entries = [entry for entry in transporter_entries if not '/transporters/rat' in entry.get('href')]
transporters = pd.DataFrame(transporter_entries, columns=['name'])

# %%
transporters
# Out:
#             name
# 0          ABCB1
# 1          ABCB4
# 2         ABCB11
# 3          ABCC1
# 4          ABCC2
# 5          ABCC3
# 6          ABCC4
# 7          ABCC5
# 8          ABCC6
# 9          ABCG2
# 10      OSTalpha
# 11       OSTbeta
# 12       SLC7A10
# 13       SLC10A1
# 14       SLC10A2
# 15       SLC15A1
# 16       SLC15A2
# 17       SLC22A1
# 18       SLC22A2
# 19       SLC22A3
# 20       SLC22A4
# 21       SLC22A5
# 22       SLC22A6
# 23       SLC22A7
# 24       SLC22A8
# 25      SLC22A11
# 26      SLC22A12
# 27       SLC47A1
# 28       SLC47A2
# 29       SLCO1A2
# 30       SLCO1B1
# 31       SLCO1B3
# 32       SLCO2B1
# 33  grivet_ABCB1

# %%
for name in transporters['name']:
    response = requests.get('https://rest.uniprot.org/uniprotkb/search?query='+name+'+AND+organism_id:9606&includeisoform=false')
    response = response.json()['results']
    transporter['sequence'][{'name':}
    

url_list
# Out:
# ['https://rest.uniprot.org/uniprotkb/search?query=ABCB1+AND+organism_id:9606&includeisoform=false',
#  'https://rest.uniprot.org/uniprotkb/search?query=ABCB4+AND+organism_id:9606&includeisoform=false',
#  'https://rest.uniprot.org/uniprotkb/search?query=ABCB11+AND+organism_id:9606&includeisoform=false',
#  'https://rest.uniprot.org/uniprotkb/search?query=ABCC1+AND+organism_id:9606&includeisoform=false',
#  'https://rest.uniprot.org/uniprotkb/search?query=ABCC2+AND+organism_id:9606&includeisoform=false',
#  'https://rest.uniprot.org/uniprotkb/search?query=ABCC3+AND+organism_id:9606&includeisoform=false',
#  'https://rest.uniprot.org/uniprotkb/search?query=ABCC4+AND+organism_id:9606&includeisoform=false',
#  'https://rest.uniprot.org/uniprotkb/search?query=ABCC5+AND+organism_id:9606&includeisoform=false',
#  'https://rest.uniprot.org/uniprotkb/search?query=ABCC6+AND+organism_id:9606&includeisoform=false',
#  'https://rest.uniprot.org/uniprotkb/search?query=ABCG2+AND+organism_id:9606&includeisoform=false',
#  'https://rest.uniprot.org/uniprotkb/search?query=OSTalpha+AND+organism_id:9606&includeisoform=false',
#  'https://rest.uniprot.org/uniprotkb/search?query=OSTbeta+AND+organism_id:9606&includeisoform=false',
#  'https://rest.uniprot.org/uniprotkb/search?query=SLC7A10+AND+organism_id:9606&includeisoform=false',
#  'https://rest.uniprot.org/uniprotkb/search?query=SLC10A1+AND+organism_id:9606&includeisoform=false',
#  'https://rest.uniprot.org/uniprotkb/search?query=SLC10A2+AND+organism_id:9606&includeisoform=false',
#  'https://rest.uniprot.org/uniprotkb/search?query=SLC15A1+AND+organism_id:9606&includeisoform=false',
#  'https://rest.uniprot.org/uniprotkb/search?query=SLC15A2+AND+organism_id:9606&includeisoform=false',
#  'https://rest.uniprot.org/uniprotkb/search?query=SLC22A1+AND+organism_id:9606&includeisoform=false',
#  'https://rest.uniprot.org/uniprotkb/search?query=SLC22A2+AND+organism_id:9606&includeisoform=false',
#  'https://rest.uniprot.org/uniprotkb/search?query=SLC22A3+AND+organism_id:9606&includeisoform=false',
#  'https://rest.uniprot.org/uniprotkb/search?query=SLC22A4+AND+organism_id:9606&includeisoform=false',
#  'https://rest.uniprot.org/uniprotkb/search?query=SLC22A5+AND+organism_id:9606&includeisoform=false',
#  'https://rest.uniprot.org/uniprotkb/search?query=SLC22A6+AND+organism_id:9606&includeisoform=false',
#  'https://rest.uniprot.org/uniprotkb/search?query=SLC22A7+AND+organism_id:9606&includeisoform=false',
#  'https://rest.uniprot.org/uniprotkb/search?query=SLC22A8+AND+organism_id:9606&includeisoform=false',
#  'https://rest.uniprot.org/uniprotkb/search?query=SLC22A11+AND+organism_id:9606&includeisoform=false',
#  'https://rest.uniprot.org/uniprotkb/search?query=SLC22A12+AND+organism_id:9606&includeisoform=false',
#  'https://rest.uniprot.org/uniprotkb/search?query=SLC47A1+AND+organism_id:9606&includeisoform=false',
#  'https://rest.uniprot.org/uniprotkb/search?query=SLC47A2+AND+organism_id:9606&includeisoform=false',
#  'https://rest.uniprot.org/uniprotkb/search?query=SLCO1A2+AND+organism_id:9606&includeisoform=false',
#  'https://rest.uniprot.org/uniprotkb/search?query=SLCO1B1+AND+organism_id:9606&includeisoform=false',
#  'https://rest.uniprot.org/uniprotkb/search?query=SLCO1B3+AND+organism_id:9606&includeisoform=false',
#  'https://rest.uniprot.org/uniprotkb/search?query=SLCO2B1+AND+organism_id:9606&includeisoform=false',
#  'https://rest.uniprot.org/uniprotkb/search?query=grivet_ABCB1+AND+organism_id:9606&includeisoform=false']

# %%
response = requests.get('https://rest.uniprot.org/uniprotkb/search?query=ABCB1+AND+organism_id:9606&includeisoform=false')

#Query: what is searched, conditions separated by +AND+
#homo sapiens= organism_id=9606
response=response.json()['results']

# %%
for resp in response:
    print(resp['primaryAccession'])
# Out:
# P08183
# P28074
# Q969Q6
# P48307
# Q2M3G0
# Q9NS86
# Q86VI4
# O75469
# O00165
# O95342
# Q9NZI8
# Q99496
# P21439
# Q9H7X2
# A8E2S6
# Q6TBL4
# A4D1D2
# F4ZUX9
# F4ZUT2
# F4ZUV0
# F4ZV79
# F4ZUV4
# F4ZUY5
# F4ZUQ5
# B5U2G4

# %%
transporters
transporters['sequence'

# %%
transporters['sequence'].
# Out:
# C:\Users\insta\AppData\Local\Temp\ipykernel_2740\3814377260.py:1: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transporters['sequence'].append(0)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[142], line 1
# ----> 1 transporters['sequence'].append(0)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:3140, in Series.append(self, to_append, ignore_index, verify_integrity)
#    3059 """
#    3060 Concatenate two or more Series.
#    3061
#    (...)
#    3130 ValueError: Indexes have overlapping values: [0, 1, 2]
#    3131 """
#    3132 warnings.warn(
#    3133     "The series.append method is deprecated "
#    3134     "and will be removed from pandas in a future version. "
#    (...)
#    3137     stacklevel=find_stack_level(),
#    3138 )
# -> 3140 return self._append(to_append, ignore_index, verify_integrity)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:3155, in Series._append(self, to_append, ignore_index, verify_integrity)
#    3153     msg = "to_append should be a Series or list/tuple of Series, got DataFrame"
#    3154     raise TypeError(msg)
# -> 3155 return concat(
#    3156     to_concat, ignore_index=ignore_index, verify_integrity=verify_integrity
#    3157 )
#
# File ~\anaconda3\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\reshape\concat.py:368, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     146 @deprecate_nonkeyword_arguments(version=None, allowed_args=["objs"])
#     147 def concat(
#     148     objs: Iterable[NDFrame] | Mapping[HashableT, NDFrame],
#    (...)
#     157     copy: bool = True,
#     158 ) -> DataFrame | Series:
#     159     """
#     160     Concatenate pandas objects along a particular axis.
#     161
#    (...)
#     366     1   3   4
#     367     """
# --> 368     op = _Concatenator(
#     369         objs,
#     370         axis=axis,
#     371         ignore_index=ignore_index,
#     372         join=join,
#     373         keys=keys,
#     374         levels=levels,
#     375         names=names,
#     376         verify_integrity=verify_integrity,
#     377         copy=copy,
#     378         sort=sort,
#     379     )
#     381     return op.get_result()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\reshape\concat.py:458, in _Concatenator.__init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     453     if not isinstance(obj, (ABCSeries, ABCDataFrame)):
#     454         msg = (
#     455             f"cannot concatenate object of type '{type(obj)}'; "
#     456             "only Series and DataFrame objs are valid"
#     457         )
# --> 458         raise TypeError(msg)
#     460     ndims.add(obj.ndim)
#     462 # get the sample
#     463 # want the highest ndim that we have, and must be non-empty
#     464 # unless all objs are empty
#
# TypeError: cannot concatenate object of type '<class 'int'>'; only Series and DataFrame objs are valid
