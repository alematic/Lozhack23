# %%
import pandas as pd
import random
random.seed(100)

#Drugs and transporter data downloaded from varidt database
smiles=pd.read_csv('data/SMILES_and_InChI_for_the_drugs_transported_by_DTs.txt',sep='\t') #Useful -> SMILES of drugs
matching= pd.read_csv('data/Synonyms_of_DTs_and_their_corresponding_drugs.txt', sep='\t')#useful -> matching between transporter and drug

# %%
ABCB1= matching[matching['Gene_name']=='ABCB1']
ABCB1.shape
# Out:
# (433, 7)

# %%
#Merge the SMILEs to ABCB1

ABCB1=pd.merge(ABCB1,smiles[['Canonical_SMILES','DrugID']],on="DrugID")
ABCB1.head(3)
# Out:
#   TransporterID Gene_name Protein_Name_generally  \
# 0       DTD0003     ABCB1       P-glycoprotein 1
# 1       DTD0003     ABCB1       P-glycoprotein 1
# 2       DTD0003     ABCB1       P-glycoprotein 1
#
#                                             Synonyms   DrugID  \
# 0  ABC20; ABCB1; ATP-binding cassette sub-family ...  DR00001
# 1  ABC20; ABCB1; ATP-binding cassette sub-family ...  DR00002
# 2  ABC20; ABCB1; ATP-binding cassette sub-family ...  DR00008
#
#                Drug_Name                                    synonyms  \
# 0  Fesoterodine fumarate                                 Toviaz (TN)
# 1               Paraquat  1,1'-dimethyl-4,4' bipyridinium dichloride
# 2             Venetoclax                                   Venclexta
#
#                                     Canonical_SMILES
# 0  CC(C)C(=O)OC1=C(C=C(C=C1)CO)C(CCN(C(C)C)C(C)C)...
# 1     C[N+]1=CC=C(C=C1)C2=CC=[N+](C=C2)C.[Cl-].[Cl-]
# 2  CC1(CCC(=C(C1)C2=CC=C(C=C2)Cl)CN3CCN(CC3)C4=CC...

# %%
#Create test dataframe: 
col_testdf=['DrugID', 'Drug_Name','Canonical_SMILES','substrate'] #Substrate: 1 if is substrate, 0 if not

idx_pos_test = random.sample(range(0, ABCB1.shape[0]),10)
test_df = pd.DataFrame(data= ABCB1.iloc[idx_pos_test][col_testdf[0:3]],columns= col_testdf)
test_df['substrate']=1

#Get drugs that are supposedly not ABCB1 targets
notABCB1 = smiles[~smiles['DrugID'].isin(ABCB1['DrugID'])]
idx_neg_test = random.sample(range(0, notABCB1.shape[0]),10)
testneg_df=pd.DataFrame(data= notABCB1.iloc[idx_neg_test][col_testdf[0:3]],columns= col_testdf)
testneg_df['substrate']=0
test_df = pd.concat(objs=[test_df,testneg_df], axis=0)

#Drop of those drugs from ABCB1 dataset
ABCB1 = ABCB1.drop(index=idx_pos_test)
display(~test_df['DrugID'].apply(lambda x:x in (ABCB1['DrugID']))) #Test molecule not in database anymore
test_df.head(13)
# Out:
# 74     True
# 235    True
# 232    True
# 394    True
# 89     True
# 361    True
# 201    True
# 374    True
# 179    True
# 221    True
# 500    True
# 795    True
# 92     True
# 526    True
# 99     True
# 74     True
# 728    True
# 443    True
# 243    True
# 44     True
# Name: DrugID, dtype: bool
#       DrugID                 Drug_Name  \
# 74   DR00182                 Dasatinib
# 235  DR00668               Nisoldipine
# 232  DR00658              Fluphenazine
# 394  DR01484                   Apafant
# 89   DR00220       Eliglustat tartrate
# 361  DR01399               Mithramycin
# 201  DR00521                 Clonidine
# 374  DR01424               Droloxifene
# 179  DR00448              Cyclosporine
# 221  DR00613              Dipyridamole
# 500  DR00701                Fosinopril
# 795  DR01460  Phenethyl isothiocyanate
# 92   DR00099                  Iloprost
#
#                                       Canonical_SMILES  substrate
# 74   CC1=C(C(=CC=C1)Cl)NC(=O)C2=CN=C(S2)NC3=NC(=NC(...          1
# 235  CC1=C(C(C(=C(N1)C)C(=O)OCC(C)C)C2=CC=CC=C2[N+]...          1
# 232  C1CN(CCN1CCCN2C3=CC=CC=C3SC4=C2C=C(C=C4)C(F)(F...          1
# 394  Cc1nnc2CN=C(c3ccccc3Cl)c4cc(CCC(=O)N5CCOCC5)sc...          1
# 89   CCCCCCCC(=O)NC(CN1CCCC1)C(C2=CC3=C(C=C2)OCCO3)...          1
# 361  CC1C(C(CC(O1)OC2CC(OC(C2O)C)OC3=CC4=CC5=C(C(=O...          1
# 201                       C1CN=C(N1)NC2=C(C=CC=C2Cl)Cl          1
# 374  C(=C(\c1ccccc1)/CC)(/c1cc(O)ccc1)\c1ccc(cc1)OC...          1
# 179  CCC1C(=O)N(CC(=O)N(C(C(=O)NC(C(=O)N(C(C(=O)NC(...          1
# 221  C1CCN(CC1)C2=NC(=NC3=C2N=C(N=C3N4CCCCC4)N(CCO)...          1
# 500  CCC(=O)OC(C(C)C)OP(=O)(CCCCC1=CC=CC=C1)CC(=O)N...          0
# 795                                  C(=S)=NCCc1ccccc1          0
# 92        CC#CCC(C)C(C=CC1C(CC2C1CC(=CCCCC(=O)O)C2)O)O          0

# %%
display(test_df['DrugID'].apply(lambda x:x in (ABCB1['DrugID'])))
# Out:
# 74     False
# 235    False
# 232    False
# 394    False
# 89     False
# 361    False
# 201    False
# 374    False
# 179    False
# 221    False
# Name: DrugID, dtype: bool

# %%
#Get good SMILEs from pubCHEM API
import pubchempy as pcp
name = smiles[smiles['DrugID']=="DR00001"]['Drug_Name'][0]
c= pcp.get_compounds(name,'name')
c=c[0]
#gotsmile= requests.get("https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/inchi/"+inchi+"/property/smiles/JSON")

# %%
c=c.to_dict(properties=['inchi','canonical_smiles'])
c['canonical_smiles']
# Out:
# 'CC(C)C(=O)OC1=C(C=C(C=C1)CO)C(CCN(C(C)C)C(C)C)C2=CC=CC=C2.C(=CC(=O)O)C(=O)O'

# %%
#Retrieve good smiles from pubchem database from the name, some SMILES are not correct in the  varidt database
#Need to look for: is there only one chemical compound found with the name? Is there something found for it?
new_smiles=[]
multiple_ans=[]
for name in smiles['Drug_Name']:
    c=pcp.get_compounds(name,'name')
    if len(c)==1:
        multiple_ans.append(0)
        c=c[0]
        c=c.to_dict(properties=['canonical_smiles'])
        new_smiles.append(c['canonical_smiles'])
    elif len(c)>1:
        multiple_ans.append(1)
        n_s=[]
        for comp in c:
            comp=comp.to_dict(properties=['canonical_smiles'])
            n_s.append(comp['canonical_smiles'])
        new_smiles.append(n_s)
    else:
        print('Problem drug '+name+' has no answers')
        multiple_ans.append('NaN')
        new_smiles.append('NaN')

smiles.insert(smiles.shape[1],'new_smiles',new_smiles)
smiles.insert(smiles.shape[1],'multiple_ans',multiple_ans)
# Out:
# Problem drug Creatine ALS-08 has no answers
# Problem drug Zinc salts has no answers
# Problem drug Vasopressin has no answers
# Problem drug Arsenite has no answers
# Problem drug Epipodophyllotoxins has no answers
# Problem drug Carboxydichlorofluorescein has no answers
# Problem drug Beta-lactam antibiotics has no answers
# Problem drug Antiparasitics has no answers
# Problem drug Amino acids has no answers
# Problem drug Peptides has no answers
# Problem drug Sodium phosphate dibasic/Sodium phosphate monobasic has no answers
# C:\Users\insta\anaconda3\Lib\site-packages\pubchempy.py:563: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if self.charge is not 0:
# C:\Users\insta\anaconda3\Lib\site-packages\pubchempy.py:563: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if self.charge is not 0:
# C:\Users\insta\anaconda3\Lib\site-packages\pubchempy.py:563: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if self.charge is not 0:
# C:\Users\insta\anaconda3\Lib\site-packages\pubchempy.py:563: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if self.charge is not 0:
# C:\Users\insta\anaconda3\Lib\site-packages\pubchempy.py:563: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if self.charge is not 0:
# C:\Users\insta\anaconda3\Lib\site-packages\pubchempy.py:563: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if self.charge is not 0:
# C:\Users\insta\anaconda3\Lib\site-packages\pubchempy.py:563: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if self.charge is not 0:
# C:\Users\insta\anaconda3\Lib\site-packages\pubchempy.py:563: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if self.charge is not 0:
# C:\Users\insta\anaconda3\Lib\site-packages\pubchempy.py:563: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if self.charge is not 0:
# C:\Users\insta\anaconda3\Lib\site-packages\pubchempy.py:563: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if self.charge is not 0:
# C:\Users\insta\anaconda3\Lib\site-packages\pubchempy.py:563: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if self.charge is not 0:
# C:\Users\insta\anaconda3\Lib\site-packages\pubchempy.py:563: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if self.charge is not 0:
# C:\Users\insta\anaconda3\Lib\site-packages\pubchempy.py:563: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if self.charge is not 0:
# C:\Users\insta\anaconda3\Lib\site-packages\pubchempy.py:563: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if self.charge is not 0:
# C:\Users\insta\anaconda3\Lib\site-packages\pubchempy.py:563: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if self.charge is not 0:
# C:\Users\insta\anaconda3\Lib\site-packages\pubchempy.py:563: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if self.charge is not 0:
# C:\Users\insta\anaconda3\Lib\site-packages\pubchempy.py:563: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if self.charge is not 0:
# C:\Users\insta\anaconda3\Lib\site-packages\pubchempy.py:563: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if self.charge is not 0:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[33], line 6
#       4 multiple_ans=[]
#       5 for name in smiles['Drug_Name']:
# ----> 6     c=pcp.get_compounds(name,'name')
#       7     if len(c)==1:
#       8         multiple_ans.append(0)
#
# File ~\anaconda3\Lib\site-packages\pubchempy.py:321, in get_compounds(identifier, namespace, searchtype, as_dataframe, **kwargs)
#     312 def get_compounds(identifier, namespace='cid', searchtype=None, as_dataframe=False, **kwargs):
#     313     """Retrieve the specified compound records from PubChem.
#     314
#     315     :param identifier: The compound identifier to use as a search query.
#    (...)
#     319                          :class:`~pandas.DataFrame` and return that.
#     320     """
# --> 321     results = get_json(identifier, namespace, searchtype=searchtype, **kwargs)
#     322     compounds = [Compound(r) for r in results['PC_Compounds']] if results else []
#     323     if as_dataframe:
#
# File ~\anaconda3\Lib\site-packages\pubchempy.py:299, in get_json(identifier, namespace, domain, operation, searchtype, **kwargs)
#     297 """Request wrapper that automatically parses JSON response and supresses NotFoundError."""
#     298 try:
# --> 299     return json.loads(get(identifier, namespace, domain, operation, 'JSON', searchtype, **kwargs).decode())
#     300 except NotFoundError as e:
#     301     log.info(e)
#
# File ~\anaconda3\Lib\site-packages\pubchempy.py:292, in get(identifier, namespace, domain, operation, output, searchtype, **kwargs)
#     290             response = request(identifier, namespace, domain, operation, output, searchtype, **kwargs).read()
#     291 else:
# --> 292     response = request(identifier, namespace, domain, operation, output, searchtype, **kwargs).read()
#     293 return response
#
# File ~\anaconda3\Lib\site-packages\pubchempy.py:271, in request(identifier, namespace, domain, operation, output, searchtype, **kwargs)
#     269     log.debug('Request URL: %s', apiurl)
#     270     log.debug('Request data: %s', postdata)
# --> 271     response = urlopen(apiurl, postdata)
#     272     return response
#     273 except HTTPError as e:
#
# File ~\anaconda3\Lib\urllib\request.py:216, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     214 else:
#     215     opener = _opener
# --> 216 return opener.open(url, data, timeout)
#
# File ~\anaconda3\Lib\urllib\request.py:519, in OpenerDirector.open(self, fullurl, data, timeout)
#     516     req = meth(req)
#     518 sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 519 response = self._open(req, data)
#     521 # post-process response
#     522 meth_name = protocol+"_response"
#
# File ~\anaconda3\Lib\urllib\request.py:536, in OpenerDirector._open(self, req, data)
#     533     return result
#     535 protocol = req.type
# --> 536 result = self._call_chain(self.handle_open, protocol, protocol +
#     537                           '_open', req)
#     538 if result:
#     539     return result
#
# File ~\anaconda3\Lib\urllib\request.py:496, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     494 for handler in handlers:
#     495     func = getattr(handler, meth_name)
# --> 496     result = func(*args)
#     497     if result is not None:
#     498         return result
#
# File ~\anaconda3\Lib\urllib\request.py:1391, in HTTPSHandler.https_open(self, req)
#    1390 def https_open(self, req):
# -> 1391     return self.do_open(http.client.HTTPSConnection, req,
#    1392         context=self._context, check_hostname=self._check_hostname)
#
# File ~\anaconda3\Lib\urllib\request.py:1352, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1350     except OSError as err: # timeout error
#    1351         raise URLError(err)
# -> 1352     r = h.getresponse()
#    1353 except:
#    1354     h.close()
#
# File ~\anaconda3\Lib\http\client.py:1378, in HTTPConnection.getresponse(self)
#    1376 try:
#    1377     try:
# -> 1378         response.begin()
#    1379     except ConnectionError:
#    1380         self.close()
#
# File ~\anaconda3\Lib\http\client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File ~\anaconda3\Lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File ~\anaconda3\Lib\socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# File ~\anaconda3\Lib\ssl.py:1278, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1274     if flags != 0:
#    1275         raise ValueError(
#    1276           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1277           self.__class__)
# -> 1278     return self.read(nbytes, buffer)
#    1279 else:
#    1280     return super().recv_into(buffer, nbytes, flags)
#
# File ~\anaconda3\Lib\ssl.py:1134, in SSLSocket.read(self, len, buffer)
#    1132 try:
#    1133     if buffer is not None:
# -> 1134         return self._sslobj.read(len, buffer)
#    1135     else:
#    1136         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
#export txt files

#smiles.to_csv("data/smiles.txt",index=False,header=True)
#test_df.to_csv('data/test_drug.txt')

# %%
smiles=pd.read_csv('data/smiles.txt')
smiles.drop(axis=1,labels=['Unnamed: 0'],inplace= True)

# %%
final_smiles=[]

for i in range(smiles.shape[0]):
    drug=smiles.iloc[i]
    if drug['multiple_ans']==0:
        final_smiles.append(drug['new_smiles'])
    elif drug['multiple_ans']=='NaN':
        final_smiles.append(drug['Canonical_SMILES'])
    else: #If multiple answers from pubChem: take whatever is before the dot (main body of the compound)
        smol= str(drug['new_smiles']).split(sep=',')[0].split(sep='.')[0][2:]
        final_smiles.append(smol)

# %%
smiles['final_smiles']=final_smiles
smiles.dropna(inplace=True)
smiles
# Out:
#       DrugID              Drug_Name  \
# 0    DR00001  Fesoterodine fumarate
# 1    DR00002               Paraquat
# 2    DR00003       Lisdexamfetamine
# 3    DR00004              Gaboxadol
# 4    DR00005        L-glutamic acid
# ..       ...                    ...
# 879  DR01713        S-licarbazepine
# 880  DR01715                Parabis
# 881  DR01717                Saphris
# 883  DR01722               Gepirone
# 884  DR01725          Olamufloxacin
#
#                                                  InChI  \
# 0    InChI=1S/C26H37NO3/c1-18(2)26(29)30-25-13-12-2...
# 1    InChI=1S/C12H14N2.2ClH/c1-13-7-3-11(4-8-13)12-...
# 2    InChI=1S/C15H25N3O/c1-12(11-13-7-3-2-4-8-13)18...
# 3    InChI=1S/C6H8N2O2/c9-6-4-1-2-7-3-5(4)10-8-6/h7...
# 4    InChI=1S/C5H9NO4/c6-3(5(9)10)1-2-4(7)8/h3H,1-2...
# ..                                                 ...
# 879  InChI=1S/C15H14N2O2/c16-15(19)17-12-7-3-1-5-10...
# 880  InChI=1S/C13H10Cl2O2/c14-10-1-3-12(16)8(6-10)5...
# 881  InChI=1S/C17H16ClNO.C4H4O4/c1-19-9-14-12-4-2-3...
# 883  InChI=1S/C19H29N5O2/c1-19(2)14-16(25)24(17(26)...
# 884  InChI=1S/C20H23FN4O3/c1-9-16-13(18(26)11(19(27...
#
#                                       Canonical_SMILES  \
# 0    CC(C)C(=O)OC1=C(C=C(C=C1)CO)C(CCN(C(C)C)C(C)C)...
# 1       C[N+]1=CC=C(C=C1)C2=CC=[N+](C=C2)C.[Cl-].[Cl-]
# 2                      CC(CC1=CC=CC=C1)NC(=O)C(CCCCN)N
# 3                                   C1CNCC2=C1C(=O)NO2
# 4                                 C(CC(=O)O)C(C(=O)O)N
# ..                                                 ...
# 879             C1C(C2=CC=CC=C2N(C3=CC=CC=C31)C(=O)N)O
# 880              C1=CC(=C(C=C1Cl)CC2=C(C=CC(=C2)Cl)O)O
# 881  CN1CC2C(C1)C3=C(C=CC(=C3)Cl)OC4=CC=CC=C24.C(=C...
# 883    CC1(CC(=O)N(C(=O)C1)CCCCN2CCN(CC2)C3=NC=CC=N3)C
# 884  CC1=C2C(=C(C(=C1N3CC(C4(C3)CC4)N)F)N)C(=O)C(=C...
#
#                                             new_smiles  multiple_ans  \
# 0    CC(C)C(=O)OC1=C(C=C(C=C1)CO)C(CCN(C(C)C)C(C)C)...           0.0
# 1                   C[N+]1=CC=C(C=C1)C2=CC=[N+](C=C2)C           0.0
# 2                      CC(CC1=CC=CC=C1)NC(=O)C(CCCCN)N           0.0
# 3                                   C1CNCC2=C1C(=O)NO2           0.0
# 4                                 C(CC(=O)O)C(C(=O)O)N           0.0
# ..                                                 ...           ...
# 879             C1C(C2=CC=CC=C2N(C3=CC=CC=C31)C(=O)N)O           0.0
# 880              C1=CC(=C(C=C1Cl)CC2=C(C=CC(=C2)Cl)O)O           0.0
# 881  CN1CC2C(C1)C3=C(C=CC(=C3)Cl)OC4=CC=CC=C24.C(=C...           0.0
# 883    CC1(CC(=O)N(C(=O)C1)CCCCN2CCN(CC2)C3=NC=CC=N3)C           0.0
# 884  CC1=C2C(=C(C(=C1N3CC(C4(C3)CC4)N)F)N)C(=O)C(=C...           0.0
#
#                                           final_smiles
# 0    CC(C)C(=O)OC1=C(C=C(C=C1)CO)C(CCN(C(C)C)C(C)C)...
# 1                   C[N+]1=CC=C(C=C1)C2=CC=[N+](C=C2)C
# 2                      CC(CC1=CC=CC=C1)NC(=O)C(CCCCN)N
# 3                                   C1CNCC2=C1C(=O)NO2
# 4                                 C(CC(=O)O)C(C(=O)O)N
# ..                                                 ...
# 879             C1C(C2=CC=CC=C2N(C3=CC=CC=C31)C(=O)N)O
# 880              C1=CC(=C(C=C1Cl)CC2=C(C=CC(=C2)Cl)O)O
# 881  CN1CC2C(C1)C3=C(C=CC(=C3)Cl)OC4=CC=CC=C24.C(=C...
# 883    CC1(CC(=O)N(C(=O)C1)CCCCN2CCN(CC2)C3=NC=CC=N3)C
# 884  CC1=C2C(=C(C(=C1N3CC(C4(C3)CC4)N)F)N)C(=O)C(=C...
#
# [867 rows x 7 columns]

# %% [markdown]
# ## Making dataframe for all transporters

# %%
matching=pd.merge(left=matching,right=smiles[['DrugID','final_smiles']],on='DrugID')

# %%
matching.to_csv("data/fulldata.csv")
